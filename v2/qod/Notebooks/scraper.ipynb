# %%
import bs4 as bs
import lxml
from urllib.request import Request, urlopen
import time
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains as ac
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import ElementNotInteractableException

url="https://www.wattpad.com/story/112734148-queen-of-death-%E2%9C%94"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
sauce = urlopen(req).read()
soup = bs.BeautifulSoup(sauce,'lxml')
links = []

for item in soup.find_all('a'):
    item = item.get('href')
    item = str(item)
    item = "https://www.wattpad.com" + item
    links.append(item)
    
driver = webdriver.Chrome("..\chromedriver_win32\chromedriver.exe")

# %%
links
# Out:
# ['https://www.wattpad.com/?nextUrl=/story/112734148-queen-of-death-%E2%9C%94',
#  'https://www.wattpad.com#',
#  'https://www.wattpad.com/catalog/paidstories',
#  'https://www.wattpad.com/stories/horror',
#  'https://www.wattpad.com/stories/poetry',
#  'https://www.wattpad.com/list/551324301',
#  'https://www.wattpad.com/stories/humor',
#  'https://www.wattpad.com/stories/romance',
#  'https://www.wattpad.com/stories/adventure',
#  'https://www.wattpad.com/stories/lgbt',
#  'https://www.wattpad.com/stories/sciencefiction',
#  'https://www.wattpad.com/stories/contemporarylit',
#  'https://www.wattpad.com/stories/mystery',
#  'https://www.wattpad.com/stories/shortstory',
#  'https://www.wattpad.com/stories/diverselit',
#  'https://www.wattpad.com/stories/newadult',
#  'https://www.wattpad.com/stories/teenfiction',
#  'https://www.wattpad.com/stories/fanfiction',
#  'https://www.wattpad.com/stories/nonfiction',
#  'https://www.wattpad.com/stories/thriller',
#  'https://www.wattpad.com/stories/fantasy',
#  'https://www.wattpad.com/stories/paranormal',
#  'https://www.wattpad.com/stories/werewolf',
#  'https://www.wattpad.com/stories/historicalfiction',
#  'https://www.wattpad.com/featured/551324301',
#  'https://www.wattpad.com/featured/923492479',
#  'https://www.wattpad.com/featured/703389905',
#  'https://www.wattpad.com/featured/814773184',
#  'https://www.wattpad.com/featured/960279561',
#  'https://www.wattpad.com#',
#  'https://www.wattpad.com/awards',
#  'https://www.wattpad.com#',
#  'https://www.wattpad.com/?nexturl=/myworks/new',
#  'https://www.wattpad.com/?nexturl=/myworks',
#  'https://www.wattpad.com/writers/',
#  'https://www.wattpad.com/go/writing-contests/',
#  'https://www.wattpad.comhttps://www.wattpad.com/premium',
#  'https://www.wattpad.com/login?nexturl=%2Fstory%2F112734148-queen-of-death-%25E2%259C%2594',
#  'https://www.wattpad.com/?nexturl=%2Fstory%2F112734148-queen-of-death-%25E2%259C%2594',
#  'https://www.wattpad.com/user/rubyruins',
#  'https://www.wattpad.com/user/rubyruins',
#  'https://www.wattpad.comhttps://www.facebook.com/sharer.php?u=https%3A%2F%2Fwww.wattpad.com%2Fstory%2F112734148-queen-of-death-%25E2%259C%2594%3Futm_source%3Dweb%26utm_medium%3Dfacebook%26utm_content%3Dshare_info',
#  'https://www.wattpad.comhttps://twitter.com/intent/tweet?text=QUEEN+OF+DEATH+%E2%9C%94+%23wattpad&url=https%3A%2F%2Fwww.wattpad.com%2Fstory%2F112734148-queen-of-death-%25E2%259C%2594%3Futm_source%3Dweb%26utm_medium%3Dtwitter%26utm_content%3Dshare_info',
#  'https://www.wattpad.com/426351190-queen-of-death',
#  'https://www.wattpad.com/stories/-romance',
#  'https://www.wattpad.com/stories/action',
#  'https://www.wattpad.com/stories/adventure',
#  'https://www.wattpad.com/stories/drama',
#  'https://www.wattpad.com/stories/fantasy',
#  'https://www.wattpad.com/stories/fantasy-romance',
#  'https://www.wattpad.com/stories/fantasyadventure',
#  'https://www.wattpad.com/stories/fiction',
#  'https://www.wattpad.com/stories/greek',
#  'https://www.wattpad.com/stories/hades',
#  'https://www.wattpad.com/stories/king',
#  'https://www.wattpad.com/stories/love',
#  'https://www.wattpad.com/stories/magic',
#  'https://www.wattpad.com/stories/mature',
#  'https://www.wattpad.com/stories/mythology',
#  'https://www.wattpad.com/stories/persephone',
#  'https://www.wattpad.com/stories/queen',
#  'https://www.wattpad.com/stories/romance',
#  'https://www.wattpad.com#',
#  'https://www.wattpad.com#',
#  'https://www.wattpad.com/426351190-queen-of-death',
#  'https://www.wattpad.com/463167777-queen-of-death-%E2%9C%94-prelude',
#  'https://www.wattpad.com/465917172-queen-of-death-%E2%9C%94-prologue',
#  'https://www.wattpad.com/426352438-queen-of-death-%E2%9C%94-part-one',
#  'https://www.wattpad.com/524290860-queen-of-death-%E2%9C%94-one',
#  'https://www.wattpad.com/529233871-queen-of-death-%E2%9C%94-two',
#  'https://www.wattpad.com/532931178-queen-of-death-%E2%9C%94-three',
#  'https://www.wattpad.com/536054535-queen-of-death-%E2%9C%94-four',
#  'https://www.wattpad.com/542831600-queen-of-death-%E2%9C%94-five',
#  'https://www.wattpad.com/544171595-queen-of-death-%E2%9C%94-six',
#  'https://www.wattpad.com/559489646-queen-of-death-%E2%9C%94-seven',
#  'https://www.wattpad.com/580594681-queen-of-death-%E2%9C%94-eight',
#  'https://www.wattpad.com/594740450-queen-of-death-%E2%9C%94-nine',
#  'https://www.wattpad.com/600485122-queen-of-death-%E2%9C%94-ten',
#  'https://www.wattpad.com/617358539-queen-of-death-%E2%9C%94-eleven',
#  'https://www.wattpad.com/489667883-queen-of-death-%E2%9C%94-twelve',
#  'https://www.wattpad.com/742813928-queen-of-death-%E2%9C%94-thirteen',
#  'https://www.wattpad.com/746685894-queen-of-death-%E2%9C%94-fourteen',
#  'https://www.wattpad.com/749213041-queen-of-death-%E2%9C%94-part-two',
#  'https://www.wattpad.com/753928534-queen-of-death-%E2%9C%94-fifteen',
#  'https://www.wattpad.com/759187112-queen-of-death-%E2%9C%94-sixteen',
#  'https://www.wattpad.com/763907400-queen-of-death-%E2%9C%94-seventeen',
#  'https://www.wattpad.com/769451707-queen-of-death-%E2%9C%94-eighteen',
#  'https://www.wattpad.com/776550329-queen-of-death-%E2%9C%94-nineteen',
#  'https://www.wattpad.com/785324458-queen-of-death-%E2%9C%94-twenty',
#  'https://www.wattpad.com/824260520-queen-of-death-%E2%9C%94-twenty-one',
#  'https://www.wattpad.com/828881015-queen-of-death-%E2%9C%94-twenty-two',
#  'https://www.wattpad.com/story/147805752-from-the-ashes-coming-soon',
#  'https://www.wattpad.com/story/55250680-nox-stellata-%E2%9C%93',
#  'https://www.wattpad.com/story/98243394-orc-wars-uprising',
#  'https://www.wattpad.com/story/199753113-the-collectors',
#  'https://www.wattpad.com/story/91160309-moulin-rouge-graphics-closed',
#  'https://www.wattpad.com/story/93672421-beginnings-of-graves',
#  'https://www.wattpad.com/story/67590216-cupid%27s-curse',
#  'https://www.wattpad.com/story/184718191-a-flower-in-the-dark',
#  'https://www.wattpad.com/story/108938641-smoke-and-fire-on-going',
#  'https://www.wattpad.com/story/96957534-crown-of-glass-%E2%9C%94',
#  'https://www.wattpad.com/paidstories',
#  'https://www.wattpad.com/premium',
#  'https://www.wattpad.com/getmobile',
#  'https://www.wattpad.com/settings/language?jq=true',
#  'https://www.wattpad.com/writers',
#  'https://www.wattpad.comhttp://business.wattpad.com',
#  'https://www.wattpad.comhttps://company.wattpad.com/work-at-wattpad',
#  'https://www.wattpad.comhttps://company.wattpad.com/press',
#  'https://www.wattpad.com/terms',
#  'https://www.wattpad.com/privacy',
#  'https://www.wattpad.comhttps://support.wattpad.com']

# %%
links = links[69:130]

# %%
links
# Out:
# ['https://www.wattpad.com/426351190-queen-of-death',
#  'https://www.wattpad.com/463167777-queen-of-death-%E2%9C%94-prelude',
#  'https://www.wattpad.com/465917172-queen-of-death-%E2%9C%94-prologue',
#  'https://www.wattpad.com/426352438-queen-of-death-%E2%9C%94-part-one',
#  'https://www.wattpad.com/524290860-queen-of-death-%E2%9C%94-one',
#  'https://www.wattpad.com/529233871-queen-of-death-%E2%9C%94-two',
#  'https://www.wattpad.com/532931178-queen-of-death-%E2%9C%94-three',
#  'https://www.wattpad.com/536054535-queen-of-death-%E2%9C%94-four',
#  'https://www.wattpad.com/542831600-queen-of-death-%E2%9C%94-five',
#  'https://www.wattpad.com/544171595-queen-of-death-%E2%9C%94-six',
#  'https://www.wattpad.com/559489646-queen-of-death-%E2%9C%94-seven',
#  'https://www.wattpad.com/580594681-queen-of-death-%E2%9C%94-eight',
#  'https://www.wattpad.com/594740450-queen-of-death-%E2%9C%94-nine',
#  'https://www.wattpad.com/600485122-queen-of-death-%E2%9C%94-ten',
#  'https://www.wattpad.com/617358539-queen-of-death-%E2%9C%94-eleven',
#  'https://www.wattpad.com/489667883-queen-of-death-%E2%9C%94-twelve',
#  'https://www.wattpad.com/742813928-queen-of-death-%E2%9C%94-thirteen',
#  'https://www.wattpad.com/746685894-queen-of-death-%E2%9C%94-fourteen',
#  'https://www.wattpad.com/749213041-queen-of-death-%E2%9C%94-part-two',
#  'https://www.wattpad.com/753928534-queen-of-death-%E2%9C%94-fifteen',
#  'https://www.wattpad.com/759187112-queen-of-death-%E2%9C%94-sixteen',
#  'https://www.wattpad.com/763907400-queen-of-death-%E2%9C%94-seventeen',
#  'https://www.wattpad.com/769451707-queen-of-death-%E2%9C%94-eighteen',
#  'https://www.wattpad.com/776550329-queen-of-death-%E2%9C%94-nineteen',
#  'https://www.wattpad.com/785324458-queen-of-death-%E2%9C%94-twenty',
#  'https://www.wattpad.com/824260520-queen-of-death-%E2%9C%94-twenty-one',
#  'https://www.wattpad.com/828881015-queen-of-death-%E2%9C%94-twenty-two',
#  'https://www.wattpad.com/847133393-queen-of-death-%E2%9C%94-twenty-three',
#  'https://www.wattpad.com/850664984-queen-of-death-%E2%9C%94-twenty-four',
#  'https://www.wattpad.com/853053559-queen-of-death-%E2%9C%94-twenty-five',
#  'https://www.wattpad.com/859302513-queen-of-death-%E2%9C%94-twenty-six',
#  'https://www.wattpad.com/861569378-queen-of-death-%E2%9C%94-twenty-seven',
#  'https://www.wattpad.com/867425883-queen-of-death-%E2%9C%94-twenty-eight',
#  'https://www.wattpad.com/870447004-queen-of-death-%E2%9C%94-twenty-nine',
#  'https://www.wattpad.com/875707220-queen-of-death-%E2%9C%94-thirty',
#  'https://www.wattpad.com/879481637-queen-of-death-%E2%9C%94-thirty-one',
#  'https://www.wattpad.com/882018884-queen-of-death-%E2%9C%94-thiry-two',
#  'https://www.wattpad.com/887212635-queen-of-death-%E2%9C%94-thirty-three',
#  'https://www.wattpad.com/890916275-queen-of-death-%E2%9C%94-thirty-four',
#  'https://www.wattpad.com/894309042-queen-of-death-%E2%9C%94-thirty-five',
#  'https://www.wattpad.com/902745875-queen-of-death-%E2%9C%94-thirty-six',
#  'https://www.wattpad.com/907678073-queen-of-death-%E2%9C%94-thirty-seven',
#  'https://www.wattpad.com/910501086-queen-of-death-%E2%9C%94-thirty-eight',
#  'https://www.wattpad.com/917307807-queen-of-death-%E2%9C%94-thirty-nine',
#  'https://www.wattpad.com/921671198-queen-of-death-%E2%9C%94-forty',
#  'https://www.wattpad.com/923686418-queen-of-death-%E2%9C%94-part-three',
#  'https://www.wattpad.com/926981506-queen-of-death-%E2%9C%94-forty-one',
#  'https://www.wattpad.com/930103474-queen-of-death-%E2%9C%94-forty-two',
#  'https://www.wattpad.com/934348751-queen-of-death-%E2%9C%94-forty-three',
#  'https://www.wattpad.com/936875324-queen-of-death-%E2%9C%94-forty-four',
#  'https://www.wattpad.com/941216622-queen-of-death-%E2%9C%94-forty-five',
#  'https://www.wattpad.com/944744268-queen-of-death-%E2%9C%94-forty-six',
#  'https://www.wattpad.com/948198169-queen-of-death-%E2%9C%94-forty-seven',
#  'https://www.wattpad.com/952006094-queen-of-death-%E2%9C%94-forty-eight',
#  'https://www.wattpad.com/958991881-queen-of-death-%E2%9C%94-forty-nine',
#  'https://www.wattpad.com/962265834-queen-of-death-%E2%9C%94-fifty',
#  'https://www.wattpad.com/965509810-queen-of-death-%E2%9C%94-fifty-one',
#  'https://www.wattpad.com/975719460-queen-of-death-%E2%9C%94-fifty-two',
#  'https://www.wattpad.com/979553322-queen-of-death-%E2%9C%94-epilogue',
#  'https://www.wattpad.com/979553795-queen-of-death-%E2%9C%94-postlude',
#  'https://www.wattpad.com/519296533-queen-of-death-%E2%9C%94-final-note']

# %%
def scrapey(i):
    driver.get(links[i])
    time.sleep(2)
    try:
        for i in range(500):
            time.sleep(1)
            find = driver.find_element_by_class_name('on-showmore')
            find.send_keys(Keys.ARROW_DOWN)
            try:
                driver.find_element_by_class_name('on-showmore').click()
            except:
                pass
    finally:
        print("Scrolled to bottom.")
        l = driver.find_elements_by_class_name('comment')
        c = driver.find_elements_by_xpath("//a[@href = '#']")[3].text
        r = driver.find_elements_by_xpath("//span[@class = 'reads']")[0].text
        v = driver.find_elements_by_xpath("//span[@class = 'votes']")[0].text
        title = driver.find_elements_by_class_name('panel')
        title = title[0].text.split('\n')[0]
        print(title)
        print("Comments found", len(l))
        print("Total comments", c)
        print("Total votes", v)
        print("Total reads", r)
        with open('chapterdata.csv', mode='a') as f:
            f.write("{},{},{},{},{}".format(c, len(l), r, v, title))
            f.write("\n")
        f.closed

        with open('chaptercomments.csv', mode='a', encoding='utf-8') as f:
            for i in l:
                mycomment = i.text.split('\n')
                mycomment.insert(0, title)
                comlen = len(mycomment)
                linesoftext = comlen - 5
                if comlen > 5:
                    mycomment[3:comlen-1] = [' '.join(mycomment[3:comlen-1])]
                    mycomment[3] = mycomment[3].replace(',', ' ')
                f.write("{},{},{},{}".format(mycomment[0], mycomment[1], mycomment[2], mycomment[3]))
                f.write("\n")
        print("Done writing")
        f.closed

# %%
for i in range(len(links)):
    try:
        scrapey(i)
    except ElementNotInteractableException:
        print("All done")
# Out:
# Scrolled to bottom.
# QUEEN OF DEATH
# Comments found 349
# Total comments 592
# Total votes 751
# Total reads 17.7K
# Done writing
# All done
# Scrolled to bottom.
# PRELUDE
# Comments found 150
# Total comments 333
# Total votes 704
# Total reads 10.2K
# Done writing
# All done
# Scrolled to bottom.
# PROLOGUE
# Comments found 425
# Total comments 676
# Total votes 803
# Total reads 10.6K
# Done writing
# All done
# Scrolled to bottom.
# PART ONE
# Comments found 30
# Total comments 56
# Total votes 481
# Total reads 6.5K
# Done writing
# All done
# Scrolled to bottom.
# ONE
# Comments found 374
# Total comments 576
# Total votes 686
# Total reads 9K
# Done writing
# All done
# Scrolled to bottom.
# TWO
# Comments found 329
# Total comments 478
# Total votes 658
# Total reads 7.5K
# Done writing
# All done
# Scrolled to bottom.
# THREE
# Comments found 202
# Total comments 322
# Total votes 629
# Total reads 6.6K
# Done writing
# All done
# Scrolled to bottom.
# FOUR
# Comments found 290
# Total comments 404
# Total votes 616
# Total reads 6.3K
# Done writing
# All done
# Scrolled to bottom.
# FIVE
# Comments found 260
# Total comments 386
# Total votes 587
# Total reads 6.7K
# Done writing
# All done
# Scrolled to bottom.
# SIX
# Comments found 245
# Total comments 371
# Total votes 594
# Total reads 6.3K
# Done writing
# All done
# Scrolled to bottom.
# SEVEN
# Comments found 229
# Total comments 319
# Total votes 572
# Total reads 6.8K
# Done writing
# All done
# Scrolled to bottom.
# EIGHT
# Comments found 84
# Total comments 111
# Total votes 531
# Total reads 6K
# Done writing
# All done
# Scrolled to bottom.
# NINE
# Comments found 50
# Total comments 85
# Total votes 458
# Total reads 5.8K
# Done writing
# All done
# Scrolled to bottom.
# TEN
# Comments found 237
# Total comments 374
# Total votes 492
# Total reads 5.9K
# Done writing
# All done
# Scrolled to bottom.
# ELEVEN
# Comments found 98
# Total comments 174
# Total votes 432
# Total reads 5.7K
# Done writing
# All done
# Scrolled to bottom.
# TWELVE
# Comments found 211
# Total comments 387
# Total votes 517
# Total reads 6.1K
# Done writing
# All done
# Scrolled to bottom.
# THIRTEEN
# Comments found 134
# Total comments 210
# Total votes 348
# Total reads 4.4K
# Done writing
# All done
# Scrolled to bottom.
# FOURTEEN
# Comments found 143
# Total comments 208
# Total votes 358
# Total reads 4.5K
# Done writing
# All done
# Scrolled to bottom.
# PART TWO
# Comments found 9
# Total comments 17
# Total votes 266
# Total reads 3.8K
# Done writing
# All done
# Scrolled to bottom.
# FIFTEEN
# Comments found 91
# Total comments 163
# Total votes 296
# Total reads 4.4K
# Done writing
# All done
# Scrolled to bottom.
# SIXTEEN
# Comments found 138
# Total comments 273
# Total votes 309
# Total reads 4K
# Done writing
# All done
# Scrolled to bottom.
# SEVENTEEN
# Comments found 118
# Total comments 188
# Total votes 306
# Total reads 3.9K
# Done writing
# All done
# Scrolled to bottom.
# EIGHTEEN
# Comments found 113
# Total comments 182
# Total votes 296
# Total reads 4.1K
# Done writing
# All done
# Scrolled to bottom.
# NINETEEN
# Comments found 197
# Total comments 278
# Total votes 266
# Total reads 3.6K
# Done writing
# All done
# Scrolled to bottom.
# TWENTY
# Comments found 161
# Total comments 207
# Total votes 254
# Total reads 3.4K
# Done writing
# All done
# Scrolled to bottom.
# TWENTY ONE
# Comments found 179
# Total comments 239
# Total votes 265
# Total reads 2.9K
# Done writing
# All done
# Scrolled to bottom.
# TWENTY TWO
# Comments found 143
# Total comments 171
# Total votes 242
# Total reads 3K
# Done writing
# All done
# Scrolled to bottom.
# TWENTY THREE
# Comments found 117
# Total comments 165
# Total votes 228
# Total reads 2.7K
# Done writing
# All done
# Scrolled to bottom.
# TWENTY FOUR
# Comments found 83
# Total comments 118
# Total votes 192
# Total reads 2.3K
# Done writing
# All done
# Scrolled to bottom.
# TWENTY FIVE
# Comments found 163
# Total comments 181
# Total votes 211
# Total reads 2.5K
# Done writing
# All done
# Scrolled to bottom.
# TWENTY SIX
# Comments found 99
# Total comments 167
# Total votes 218
# Total reads 2.3K
# Done writing
# All done
# Scrolled to bottom.
# TWENTY SEVEN
# Comments found 86
# Total comments 104
# Total votes 186
# Total reads 2.2K
# Done writing
# All done
# Scrolled to bottom.
# TWENTY EIGHT
# Comments found 198
# Total comments 295
# Total votes 168
# Total reads 2.1K
# Done writing
# All done
# Scrolled to bottom.
# TWENTY NINE
# Comments found 184
# Total comments 238
# Total votes 189
# Total reads 2.2K
# Done writing
# All done
# Scrolled to bottom.
# THIRTY
# Comments found 107
# Total comments 142
# Total votes 155
# Total reads 1.9K
# Done writing
# All done
# Scrolled to bottom.
# THIRTY ONE
# Comments found 146
# Total comments 193
# Total votes 180
# Total reads 1.9K
# Done writing
# All done
# Scrolled to bottom.
# THIRY TWO
# Comments found 139
# Total comments 165
# Total votes 199
# Total reads 2K
# Done writing
# All done
# Scrolled to bottom.
# THIRTY THREE
# Comments found 71
# Total comments 116
# Total votes 163
# Total reads 1.8K
# Done writing
# All done
# Scrolled to bottom.
# THIRTY FOUR
# Comments found 82
# Total comments 106
# Total votes 180
# Total reads 1.8K
# Done writing
# All done
# Scrolled to bottom.
# THIRTY FIVE
# Comments found 180
# Total comments 197
# Total votes 164
# Total reads 2.2K
# Done writing
# All done
# Scrolled to bottom.
# THIRTY SIX
# Comments found 115
# Total comments 161
# Total votes 156
# Total reads 1.8K
# Done writing
# All done
# Scrolled to bottom.
# THIRTY SEVEN
# Comments found 84
# Total comments 110
# Total votes 147
# Total reads 1.7K
# Done writing
# All done
# Scrolled to bottom.
# THIRTY EIGHT
# Comments found 122
# Total comments 163
# Total votes 149
# Total reads 1.6K
# Done writing
# All done
# Scrolled to bottom.
# THIRTY NINE
# Comments found 102
# Total comments 151
# Total votes 126
# Total reads 1.5K
# Done writing
# All done
# Scrolled to bottom.
# FORTY
# Comments found 49
# Total comments 66
# Total votes 127
# Total reads 1.5K
# Done writing
# All done
# Scrolled to bottom.
# PART THREE
# Comments found 6
# Total comments 10
# Total votes 87
# Total reads 1.3K
# Done writing
# All done
# Scrolled to bottom.
# FORTY ONE
# Comments found 69
# Total comments 111
# Total votes 127
# Total reads 1.3K
# Done writing
# All done
# Scrolled to bottom.
# FORTY TWO
# Comments found 148
# Total comments 196
# Total votes 131
# Total reads 1.2K
# Done writing
# All done
# Scrolled to bottom.
# FORTY THREE
# Comments found 142
# Total comments 204
# Total votes 112
# Total reads 1.2K
# Done writing
# All done
# Scrolled to bottom.
# FORTY FOUR
# Comments found 103
# Total comments 158
# Total votes 122
# Total reads 1K
# Done writing
# All done
# Scrolled to bottom.
# FORTY FIVE
# Comments found 73
# Total comments 92
# Total votes 117
# Total reads 1K
# Done writing
# All done
# Scrolled to bottom.
# FORTY SIX
# Comments found 77
# Total comments 93
# Total votes 97
# Total reads 1K
# Done writing
# All done
# Scrolled to bottom.
# FORTY SEVEN
# Comments found 52
# Total comments 62
# Total votes 91
# Total reads 888
# Done writing
# All done
# Scrolled to bottom.
# FORTY EIGHT
# Comments found 69
# Total comments 98
# Total votes 103
# Total reads 916
# Done writing
# All done
# Scrolled to bottom.
# FORTY NINE
# Comments found 38
# Total comments 57
# Total votes 84
# Total reads 773
# Done writing
# All done
# Scrolled to bottom.
# FIFTY
# Comments found 67
# Total comments 93
# Total votes 96
# Total reads 867
# Done writing
# All done
# Scrolled to bottom.
# FIFTY ONE
# Comments found 88
# Total comments 90
# Total votes 101
# Total reads 850
# Done writing
# All done
# Scrolled to bottom.
# FIFTY TWO
# Comments found 95
# Total comments 110
# Total votes 101
# Total reads 754
# Done writing
# All done
# Scrolled to bottom.
# EPILOGUE
# Comments found 58
# Total comments 82
# Total votes 81
# Total reads 592
# Done writing
# All done
# Scrolled to bottom.
# POSTLUDE
# Comments found 4
# Total comments 10
# Total votes 60
# Total reads 437
# Done writing
# All done
# Scrolled to bottom.
# FINAL NOTE
# Comments found 190
# Total comments 268
# Total votes 425
# Total reads 15.1K
# Done writing
# All done

# %%
driver.close()
